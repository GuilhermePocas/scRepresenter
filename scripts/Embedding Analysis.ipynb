# %% [markdown]
# # Analysing scRepresenter embeddings
#
# In this notebook we will look the structure of the embedding object produced by scRepresenter, as well as some potential use cases. If you haven't already, please see the Preprocessing and Training notebooks.

# %%
import os
import pandas as pd
import scanpy as sc
if os.path.basename(os.getcwd()) == 'scripts':
    os.chdir('..')

# %% [markdown]
# ## The
#
# Firstly, we'll read the h5 object produced by scRepresenter.
