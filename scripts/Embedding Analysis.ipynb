# %% [markdown]
# # Analysing scRepresenter embeddings
#
# In this notebook we will look the structure of the embedding object produced by scRepresenter, as well as some potential use cases. If you haven't already, please see the Preprocessing and Training notebooks. (TODO)
